# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/model.safetensors.index.json
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/model-00003-of-00003.safetensors
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/config.json
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/preprocessor_config.json
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/README.md
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/tokenizer.json
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/model-00001-of-00003.safetensors
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/tokenizer_config.json
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/chat_template.jinja
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/model-00002-of-00003.safetensors
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/processor_config.json
# /kaggle/input/gemma-3n/transformers/gemma-3n-e2b-it/1/special_tokens_map.json
# ...

# %% [markdown]
# Gemma 3n Impact Challenge – Submission & Evaluation Overview
#
# To succeed in the Google Gemma 3n Impact Challenge, your submission must stand out visually, technically, and emotionally. This guide breaks down the submission requirements, judging criteria, and timeline to help you craft a winning entry.
#
#
# 📤 Submission Requirements
# - **1. Video Demo (Max 3 minutes)**
# Purpose: The centerpiece of your submission.
# What to Include:
# A story-driven narrative that clearly shows the problem and how your app solves it.
# A live demonstration of your project in action.
# Highlight the real-world impact and user experience.
# Platform: Upload to YouTube, TikTok, X (Twitter), or any public platform.
# Accessibility: Ensure it's viewable without login or paywall.
# - **2. Technical Writeup**
# Format: Paper or blog-style.
# Content Requirements:
# Explain your app’s architecture.
# Detail how Gemma 3n was used (e.g., on-device processing, multimodal features, mix’n’match).
# Describe the technical challenges and how you overcame them.
# Justify your design and implementation choices.
# Goal: Prove that your demo is functional and built on real engineering.
# - **3. Public Code Repository**
# Platform: GitHub, Kaggle Notebook, etc.
# Requirements:
# Fully documented and organized.
# Must clearly show the implementation of Gemma 3n.
# Judges will verify that your demo is authentic and reproducible.
# - **4. Public Project Link (Optional but Recommended)**
# Provide a live demo URL.
# Ensure it's publicly accessible and functional.
# Allows judges to interact with your application.
# 🏛️ Judging Criteria (Total: 100 Points)
#
# | Category                    | Points | Description                                                                                                                                                             |
# | --------------------------- | ------ | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Impact & Vision             | 40     | How clearly and compellingly your project addresses a real-world challenge and envisions positive, scalable change.                                                     |
# | Video Pitch & Storytelling  | 30     | Quality of storytelling, production value, and clarity of the demo. Should be engaging, inspiring, and viral-ready.                                                     |
# | Technical Depth & Execution | 30     | Demonstrated innovation in using Gemma 3n’s unique features (on-device, multimodal, mix’n’match). Code and writeup must validate a functional, well-engineered product. |

# %% [markdown]
# Gemma 3n, with its innovative architecture and multimodal capabilities, opens up a wide range of use cases and project ideas across various domains. Here are some potential applications and ideas:
#
# 1. **On-Device Healthcare Assistant**: Develop a mobile application that uses Gemma 3n to analyze medical images (e.g., X-rays, MRIs) and provide preliminary diagnostic suggestions. This could be particularly useful in remote areas with limited access to specialized healthcare professionals.
# 2. **Multilingual Customer Support Chatbot**: Leverage Gemma 3n's support for 140+ languages to build a customer support chatbot that can handle text and image inputs. This bot could assist users in multiple languages, providing solutions to common issues or escalating complex problems to human agents.
# 3. **Educational Tool for Language Learning**: Create an interactive language learning app that uses Gemma 3n to provide real-time feedback on written and spoken language exercises. The app could also use image recognition to help learners identify objects and translate them into the target language.
# 4. **Smart Home Automation Assistant**: Integrate Gemma 3n into a smart home system to create a voice-activated assistant that can understand and execute complex commands involving multiple devices. The assistant could also use visual inputs from security cameras to provide context-aware responses.
# 5. **Environmental Monitoring System**: Develop a system that uses Gemma 3n to analyze images and audio from environmental sensors to monitor wildlife, detect illegal logging, or track changes in ecosystems. This could be deployed on low-resource devices in remote locations.
# 6. **Personalized Fitness Coach**: Build a mobile app that uses Gemma 3n to analyze user inputs, including text, images of workout routines, and audio of breathing patterns, to provide personalized fitness recommendations and track progress over time.
# 7. **AI-Powered Travel Guide**: Create a travel app that uses Gemma 3n to provide real-time information about landmarks, historical sites, and local culture based on images and text inputs. The app could also offer multilingual translations and recommendations for nearby attractions.
# 8, **Content Moderation Tool**: Utilize Gemma 3n's capabilities to develop a content moderation tool that can analyze text, images, and audio for harmful or inappropriate content. This tool could be used by social media platforms, forums, and other online communities to maintain a safe environment.
# 9. **Interactive Storytelling Platform**: Design an interactive storytelling platform where users can create and share stories that incorporate text, images, and audio. Gemma 3n could be used to generate dynamic narratives based on user inputs and preferences.
# 10. **Smart Retail Assistant**: Implement Gemma 3n in a retail setting to create an assistant that can help customers find products, provide information about items, and even process transactions using voice and visual inputs.

# %% [markdown]
# ## Packages and Reference
#
# reference first steps to install from
#
# https://www.kaggle.com/code/paultimothymooney/how-to-use-gemma-3n-on-kaggle
#
# refernce code from
#
# https://www.kaggle.com/code/mpwolke/gemma-3n-me-conf-sed-and-sh-med/notebook

# %%
# !pip install timm --upgrade
# !pip install accelerate
# !pip install git+https://github.com/huggingface/transformers.git
# add more to make demo
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Download Gemma-3n

# %%
# %%time
import kagglehub

GEMMA_PATH = kagglehub.model_download("google/gemma-3n/transformers/gemma-3n-e2b-it")
# Out:
# CPU times: user 297 ms, sys: 49.8 ms, total: 347 ms
# Wall time: 1 s

# %% [markdown]
# ## Turn Your Gemma 3n Model Code Into a Shareable Kaggle Notebook Demo

# %%
# %%time
import transformers
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig

tokenizer = AutoTokenizer.from_pretrained(GEMMA_PATH, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(GEMMA_PATH, trust_remote_code=True)
prompt = "What is the capital of France?"
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
generation_config = GenerationConfig(max_new_tokens=150, do_sample=True, temperature=0.7)
outputs = model.generate(**inputs, generation_config=generation_config)
result = tokenizer.decode(outputs[0], skip_special_tokens=True)
# Out:
# 2025-07-07 10:00:47.919880: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751882448.102530      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751882448.158526      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ...

# %%
print(result)
# Out:
# What is the capital of France?
#
# Paris
# Berlin
# Rome
# Madrid
#
# The correct answer is:
#
# Paris

# %% [markdown]
# ## Wrap Model in a Function for Gradio
# Wrap your inference logic in a clean function.

# %%
# %%time
def gemma_query(input_text):
    inputs = tokenizer(input_text, return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, max_new_tokens=100)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.58 µs

# %% [markdown]
# ## Add Interactive Demo with Gradio
# Add an interactive demo so users can try your model live.

# %%
# %%time
import gradio as gr

# Define the interface
demo = gr.Interface(
    fn=gemma_query,
    inputs=gr.Textbox(label="Enter your query"),
    outputs=gr.Textbox(label="Gemma 3n Response"),
    title="Gemma 3n: [Your Project Name]",
    description="Powered by Gemma 3n – A private, offline-first, multimodal AI model.",
    examples=[["Tell me about climate change."], ["Explain photosynthesis in simple terms."]],
    theme="default"
)

# Launch the interface
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# * Running on public URL: https://56c6a25b56bb550784.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://56c6a25b56bb550784.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# CPU times: user 2.81 s, sys: 193 ms, total: 3 s
# Wall time: 4.07 s

# %% [markdown]
# ## Multilingual Customer Support Chatbot using Gemma 3n

# %% [markdown]
# Add more packages

# %%
# !pip install langdetect -q
# !pip install googletrans==4.0.0-rc1 -q
# !pip install --upgrade httpx httpcore
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.6 MB/s eta 0:00:00
# ...

# %%
# %%time
# 🧹 Clear GPU memory (before loading large models)
import torch
import gc

def clean_gpu_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()
        print(f"🧹 GPU memory cleared on: {torch.cuda.get_device_name(0)}")
    else:
        print("⚠️ No GPU available.")

clean_gpu_memory()
# Out:
# 🧹 GPU memory cleared on: Tesla T4
# CPU times: user 490 ms, sys: 60.6 ms, total: 550 ms
# Wall time: 542 ms

# %%
# %%time
import gc
import torch
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()
# Out:
# CPU times: user 424 ms, sys: 1.49 ms, total: 425 ms
# Wall time: 420 ms

# %% [markdown]
# ##  Image Generation

# %%
# %%time
# 📚 2. Load GEMMA model + tokenizer
from transformers import AutoModelForCausalLM, AutoTokenizer, TextGenerationPipeline
import torch

tokenizer = AutoTokenizer.from_pretrained(GEMMA_PATH)
model = AutoModelForCausalLM.from_pretrained(
    GEMMA_PATH,
    torch_dtype=torch.float16,
    device_map="auto",       # No bitsandbytes / quant
)

pipeline = TextGenerationPipeline(model=model, tokenizer=tokenizer)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# CPU times: user 21.5 s, sys: 14.8 s, total: 36.4 s
# Wall time: 58.2 s

# %% [markdown]
# ## Genereate Text

# %%
# %%time
# 🤖 3. Ask GEMMA a multilingual support question
def ask_gemma(user_input, lang="en"):
    prompt = f"<|start_of_turn|>user (language: {lang}): {user_input}<|end_of_turn|>\n<|start_of_turn|>model:"
    out = pipeline(
        prompt,
        max_new_tokens=64,
        do_sample=True,
        top_p=0.9,
        temperature=0.7,
        return_full_text=False
    )
    return out[0]["generated_text"].strip()
# Out:
# CPU times: user 3 µs, sys: 2 µs, total: 5 µs
# Wall time: 7.87 µs

# %% [markdown]
# ## Minimal Code to Display Image from URL

# %%
# %%time
from IPython.display import Image

IMAGE_URL = "https://storage.googleapis.com/kaggle-media/competitions/question_goose.png"
Image(url=IMAGE_URL, height=250, width=250)
# Out:
# CPU times: user 42 µs, sys: 20 µs, total: 62 µs
# Wall time: 66.5 µs
# <img src="https://storage.googleapis.com/kaggle-media/competitions/question_goose.png" width="250" height="250"/>

# %% [markdown]
# ## Personalized Fitness Coach
#
# Build a mobile app that uses Gemma 3n to analyze user inputs, including text, images of workout routines, and audio of breathing patterns, to provide personalized fitness recommendations and track progress over time.

# %%
# %%time
import requests

# Download image
img_url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/diffusers/input_image_vermeer.png"
image_path = "workout_pose.jpg"
with open(image_path, 'wb') as f:
    f.write(requests.get(img_url).content)

# Download audio
audio_url = "https://github.com/mgeier/python-audio/blob/master/examples/audio_samples/440Hz-44100Hz-1sec.wav?raw=true"
audio_path = "breathing.wav"
with open(audio_path, 'wb') as f:
    f.write(requests.get(audio_url).content)
# Out:
# CPU times: user 21.1 ms, sys: 4.44 ms, total: 25.5 ms
# Wall time: 613 ms

# %%
# %%time
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForVision2Seq, pipeline
import torchaudio

def analyze_text(user_input):
    # Text-only analysis
    return f"🧠 Based on your goal '{user_input}', increase protein intake and try HIIT 3x/week."

def analyze_image(image_path):
    # Vision-language analysis
    image = Image.open(image_path)
    prompt = "Describe and assess the workout form in this image."
    #inputs = processor(prompt, image, return_tensors="pt").to("cuda", torch.float16)
    output = model.generate(**inputs, max_new_tokens=100)
    #result = processor.decode(output[0], skip_special_tokens=True)
    return f"📸 Pose analysis: {result}"

def analyze_audio(audio_path):
    # Audio breathing pattern analysis (placeholder)
    waveform, sample_rate = torchaudio.load(audio_path)
    # Just check volume/duration for demo
    duration = waveform.shape[1] / sample_rate
    avg_volume = waveform.abs().mean().item()
    if avg_volume < 0.02:
        return "🔊 Breathing too shallow. Try deeper inhales."
    elif duration < 5:
        return "⏱️ Breathing too short. Aim for longer rhythmic breathing."
    else:
        return "✅ Breathing looks steady and controlled."

# --- Demo Input (replace with real inputs in your app)
user_text = "I want to build muscle and lose fat."

# --- Run Analysis
print(analyze_text(user_text))
#print(analyze_image(image_path))
#print(analyze_audio(audio_path))
# Out:
# 🧠 Based on your goal 'I want to build muscle and lose fat.', increase protein intake and try HIIT 3x/week.
# CPU times: user 439 ms, sys: 350 ms, total: 789 ms
# Wall time: 823 ms
